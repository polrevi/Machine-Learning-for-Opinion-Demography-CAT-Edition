# %% [markdown]
# # Analysis of the 2nd 2024 Barometer of Catalonia (pt1)
# # Preprocessing the survey
#
# Quantitative survey conducted by the Centre d'Estudis d'Opinió (CEO) between June 10 and July 8, 2024, based on a sample of 2,000 individuals. The target population is the Catalan population, and the survey gathers public opinion on politics, economy, media, and electoral behavior.
#
# The data used for the analysis can be found on the following url: https://ceo.gencat.cat/ca/barometre/detall/index.html?id=9368
#
# In this Jupyter Notebook I will preprocess the survey dataset and get a cleaned one which I can use for exploratory data analysis and training ML models.
#
# _________________________________________________

# %% [markdown]
# Libraries used for the preprocessing:

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 00. Importing the data

# %% [markdown]
# Let's start importing the file:

# %%
bar2024 = pd.read_excel('2nBar2024.xlsx')
bar2024
# Out:
#       PONDERA  ORDRE_REVISADA   REO METODOLOGIA          BOP_NUM   ANY  \
# 0           1               1  1101  Presencial  Juliol 24 -1101  2024
# 1           1               2  1101  Presencial  Juliol 24 -1101  2024
# 2           1               3  1101  Presencial  Juliol 24 -1101  2024
# 3           1               4  1101  Presencial  Juliol 24 -1101  2024
# 4           1               5  1101  Presencial  Juliol 24 -1101  2024
# ...       ...             ...   ...         ...              ...   ...
# 1995        1            1996  1101  Presencial  Juliol 24 -1101  2024
# 1996        1            1997  1101  Presencial  Juliol 24 -1101  2024
# 1997        1            1998  1101  Presencial  Juliol 24 -1101  2024
# 1998        1            1999  1101  Presencial  Juliol 24 -1101  2024
# 1999        1            2000  1101  Presencial  Juliol 24 -1101  2024
#
#          MES  DIA             DATA_INI HORA_INI  ...  INT_PARLAMENT_VOT_R  \
# 0       Juny   10  2024-10-06 00:00:00           ...  Junts per Catalunya
# 1       Juny   10  2024-10-06 00:00:00           ...         Comuns Sumar
# 2       Juny   10  2024-10-06 00:00:00           ...             En blanc
# 3       Juny   10  2024-10-06 00:00:00           ...               Altres
# 4       Juny   10  2024-10-06 00:00:00           ...             PSC/PSOE
# ...      ...  ...                  ...      ...  ...                  ...
# 1995  Juliol    5  2024-05-07 00:00:00           ...                  CUP
# 1996  Juliol    8  2024-08-07 00:00:00           ...                  ERC
# 1997  Juliol    8  2024-08-07 00:00:00           ...                  Vox
# 1998  Juliol    8  2024-08-07 00:00:00           ...                  Vox
# 1999  Juliol    8  2024-08-07 00:00:00           ...                   PP
#
#      REC_PARLAMENT_UE_VOT_R  REC_PARLAMENT_UE_VOT_CENS_R REC_PARLAMENT_VOT_R  \
# 0                                            No va votar           No ho sap
# 1              Comuns Sumar                 Comuns Sumar        Comuns Sumar
# 2                                              No ho sap            En blanc
# 3                       Nul                          Nul            PSC/PSOE
# 4                  PSC/PSOE                     PSC/PSOE            PSC/PSOE
# ...                     ...                          ...                 ...
# 1995                    ERC                          ERC                 CUP
# 1996                                         No va votar
# 1997                                         No va votar
# 1998                    VOX                          VOX                 Vox
# 1999                     PP                           PP                  PP
#
#      REC_PARLAMENT_VOT_CENS_R  \
# 0                   No ho sap
# 1                Comuns Sumar
# 2                    En blanc
# 3                    PSC/PSOE
# 4                    PSC/PSOE
# ...                       ...
# 1995                      CUP
# 1996              No va votar
# 1997              No va votar
# 1998                      Vox
# 1999                       PP
#
#                                          CIRCUIT_1101_1  \
# 0     VAL_GOV_CAT després d’INTERES_POL_PUBLICS; VAL...
# 1     VAL_GOV_ESP després d’INTERES_POL_PUBLICS; VAL...
# 2     VAL_GOV_ESP després d’INTERES_POL_PUBLICS; VAL...
# 3     VAL_GOV_ESP després d’INTERES_POL_PUBLICS; VAL...
# 4     VAL_GOV_CAT després d’INTERES_POL_PUBLICS; VAL...
# ...                                                 ...
# 1995  VAL_GOV_CAT després d’INTERES_POL_PUBLICS; VAL...
# 1996  VAL_GOV_ESP després d’INTERES_POL_PUBLICS; VAL...
# 1997  VAL_GOV_ESP després d’INTERES_POL_PUBLICS; VAL...
# 1998  VAL_GOV_ESP després d’INTERES_POL_PUBLICS; VAL...
# 1999  VAL_GOV_ESP després d’INTERES_POL_PUBLICS; VAL...
#
#                                    CIRCUIT_1101_2  \
# 0     0=màxim espanyolisme i 10=màxim catalanisme
# 1     0=màxim catalanisme i 10=màxim espanyolisme
# 2     0=màxim espanyolisme i 10=màxim catalanisme
# 3     0=màxim espanyolisme i 10=màxim catalanisme
# 4     0=màxim espanyolisme i 10=màxim catalanisme
# ...                                           ...
# 1995  0=màxim espanyolisme i 10=màxim catalanisme
# 1996  0=màxim catalanisme i 10=màxim espanyolisme
# 1997  0=màxim catalanisme i 10=màxim espanyolisme
# 1998  0=màxim espanyolisme i 10=màxim catalanisme
# 1999  0=màxim espanyolisme i 10=màxim catalanisme
#
#                                            EGP10  \
# 0
# 1                       I Classe de Serveis alta
# 2        VIIb Treballadors/es del sector primari
# 3             IVb Autònoms/es sense treballadors
# 4                       I Classe de Serveis alta
# ...                                          ...
# 1995  VIIa Feines manuals semi i no-qualificades
# 1996  VIIa Feines manuals semi i no-qualificades
# 1997  VIIa Feines manuals semi i no-qualificades
# 1998       IVa Empresaris/àries excepte classe I
# 1999  VIIa Feines manuals semi i no-qualificades
#
#                                                    EGP6 INDEX_BENESTAR
# 0                                                                    3
# 1                                I+II Classe de serveis              5
# 2     IVc+VIIb Treballadors/es i empresaris/àries se...              4
# 3                                  IVab Petita burgesia              4
# 4                                I+II Classe de serveis              4
# ...                                                 ...            ...
# 1995  VIIa Treballadors/es manuals semi i no-qualifi...              4
# 1996  VIIa Treballadors/es manuals semi i no-qualifi...              3
# 1997  VIIa Treballadors/es manuals semi i no-qualifi...              3
# 1998                               IVab Petita burgesia              4
# 1999  VIIa Treballadors/es manuals semi i no-qualifi...              4
#
# [2000 rows x 300 columns]

# %% [markdown]
# The file ```Variables_analisi``` contains the variables that will be used for the analysis and information about them.
#
# Column ```Grup``` indicates if the variable contains demographic or political information about the individual.\
# Column ```Tipus``` indicates if the variable is numerical or cathegorical.\
# Column ```Bloc_num``` indicates if the variable shares an information pattern. For example, questions related to the simpathy for political parties.

# %%
var_an = pd.read_excel('Variables_analisi.xlsx')
var_an
# Out:
#                        Variables Grup Tipus  Bloc_num
# 0                      PROVINCIA    d     c       NaN
# 1                       MUNICIPI    d     c       NaN
# 2                        COMARCA    d     c       NaN
# 3                     CIUTADANIA    d     c       NaN
# 4                           SEXE    d     c       NaN
# ..                           ...  ...   ...       ...
# 76          SENTIMENT_PERTINENCA    p     c       NaN
# 77  CLASSE_SOCIAL_SUBJECTIVA_1_7    d     c       NaN
# 78                 PERSONES_LLAR    d     n       NaN
# 79             ORIENTACIO_SEXUAL    d     c       NaN
# 80                INGRESSOS_1_15    d     c       NaN
#
# [81 rows x 4 columns]

# %% [markdown]
# Let's see the number of variables that contain political ```"p"``` and demographic ```"d"``` information:

# %%
var_an["Grup"].value_counts()
# Out:
# Grup
# p    55
# d    26
# Name: count, dtype: int64

# %% [markdown]
# I will get only the columns which are useful for the analysis.

# %%
df1 = bar2024[ list( var_an["Variables"] ) ]

# %% [markdown]
# _______________________

# %% [markdown]
# ## 01. Cleaning the data

# %% [markdown]
# ### 01.01 Missing data

# %% [markdown]
# Let's see how the missings are distributed:

# %%
df1.isna().sum()
# Out:
# PROVINCIA                       0
# MUNICIPI                        0
# COMARCA                         0
# CIUTADANIA                      0
# SEXE                            0
#                                ..
# SENTIMENT_PERTINENCA            0
# CLASSE_SOCIAL_SUBJECTIVA_1_7    0
# PERSONES_LLAR                   0
# ORIENTACIO_SEXUAL               0
# INGRESSOS_1_15                  0
# Length: 81, dtype: int64

# %%
miss_group = (df1 == " ").sum()
miss_taula = pd.DataFrame(
    {
    'variable': miss_group.index,
    'n_miss': miss_group.values
    }
)

# %% [markdown]
# There are no missings. If a data point is not encoded is saved as "Not answered".

# %%
miss_taula[miss_taula["n_miss"]>0]
# Out:
#            variable  n_miss
# 1          MUNICIPI     360
# 7  PROBLEMA_REDUIDA     136

# %% [markdown]
# It's better to fill the data with a ```No contesta```.

# %%
df1.loc[df1["MUNICIPI"]==" ", "MUNICIPI"] = "No contesta"
df1.loc[df1["PROBLEMA_REDUIDA"]==" ", "PROBLEMA_REDUIDA"] = "No contesta"

# %% [markdown]
# ### 01.02 Encoding numerical data

# %% [markdown]
# I have to encode properly different numerical variables. Some numerical variables share a codification pattern, so I will code the 4 different groups. I will create 4 functions that encode the variable for each one of the 4 groups.
#
# The numerical variables used for the analysis are the following ones with his group.

# %%
print("Number of numerical variables to encode:", var_an[var_an["Tipus"]=="n"].shape[0] )

var_an[var_an["Tipus"]=="n"]
# Out:
# Number of numerical variables to encode: 36
#                             Variables Grup Tipus  Bloc_num
# 5                                EDAT    d     n       NaN
# 23                        VAL_GOV_CAT    p     n       1.0
# 24                        VAL_GOV_ESP    p     n       1.0
# 33                         IDEOL_0_10    p     n       2.0
# 34                      IDEOL_0_10_PP    p     n       2.0
# 35                     IDEOL_0_10_ERC    p     n       2.0
# 36                     IDEOL_0_10_PSC    p     n       2.0
# 37                     IDEOL_0_10_CUP    p     n       2.0
# 38                   IDEOL_0_10_JXCAT    p     n       2.0
# 39                     IDEOL_0_10_CEC    p     n       2.0
# 40                     IDEOL_0_10_VOX    p     n       2.0
# 41                 IDEOL_0_10_ALIANCA    p     n       2.0
# 42                       ESP_CAT_0_10    p     n       3.0
# 43                    ESP_CAT_0_10_PP    p     n       3.0
# 44                   ESP_CAT_0_10_ERC    p     n       3.0
# 45                   ESP_CAT_0_10_PSC    p     n       3.0
# 46                   ESP_CAT_0_10_CUP    p     n       3.0
# 47                 ESP_CAT_0_10_JXCAT    p     n       3.0
# 48                   ESP_CAT_0_10_CEC    p     n       3.0
# 49                   ESP_CAT_0_10_VOX    p     n       3.0
# 50               ESP_CAT_0_10_ALIANCA    p     n       3.0
# 56     SIMPATIA_INDEPENDENTISTES_0_10    p     n       4.0
# 57           SIMPATIA_UNIONISTES_0_10    p     n       4.0
# 58            SIMPATIA_ESQUERRES_0_10    p     n       4.0
# 59               SIMPATIA_DRETES_0_10    p     n       4.0
# 60           SIMPATIA_FEMINISTES_0_10    p     n       4.0
# 61  SIMPATIA_CONTRARIS_FEMINISME_0_10    p     n       4.0
# 62           SIMPATIA_VOTANTS_PP_0_10    p     n       4.0
# 63          SIMPATIA_VOTANTS_PSC_0_10    p     n       4.0
# 64          SIMPATIA_VOTANTS_ERC_0_10    p     n       4.0
# 65          SIMPATIA_VOTANTS_CUP_0_10    p     n       4.0
# 66        SIMPATIA_VOTANTS_JXCAT_0_10    p     n       4.0
# 67          SIMPATIA_VOTANTS_CEC_0_10    p     n       4.0
# 68          SIMPATIA_VOTANTS_VOX_0_10    p     n       4.0
# 69      SIMPATIA_VOTANTS_ALIANCA_0_10    p     n       4.0
# 78                      PERSONES_LLAR    d     n       NaN

# %% [markdown]
# Let's create a copy of the dataframe in which I will apply the codification

# %%
df2 = df1.copy()

# %% [markdown]
# - **Group 1:** Valoration of Catalan and Spanish Government

# %%
vars_g1 = list( var_an[var_an["Bloc_num"]==1]["Variables"] )
vars_g1
# Out:
# ['VAL_GOV_CAT', 'VAL_GOV_ESP']

# %% [markdown]
# I apply the codification and I change the variable type to integer.

# %%
def codificar_G1(variable):
    df2.loc[ df2[variable] == "0 Molt dolenta", variable] = 0
    df2.loc[ df2[variable] == "10 Molt bona", variable] = 10
    df2.loc[ df2[variable] == "10  Molt bona", variable] = 10
    df2.loc[ df2[variable] == "0 Molt dolenta", variable] = 0
    df2.loc[ df2[variable] == "No ho sap", variable] = np.nan
    df2.loc[ df2[variable] == "No contesta", variable] = np.nan
    df2[variable].astype('Int64')
    
    
for var in vars_g1:
    codificar_G1(var)

# %% [markdown]
# - **Group 2:** Left-wing ideology and ranking the ideology of other political parties

# %%
vars_g2 = list( var_an[var_an["Bloc_num"]==2]["Variables"] )
vars_g2
# Out:
# ['IDEOL_0_10',
#  'IDEOL_0_10_PP',
#  'IDEOL_0_10_ERC',
#  'IDEOL_0_10_PSC',
#  'IDEOL_0_10_CUP',
#  'IDEOL_0_10_JXCAT',
#  'IDEOL_0_10_CEC',
#  'IDEOL_0_10_VOX',
#  'IDEOL_0_10_ALIANCA']

# %% [markdown]
# I apply the codification and I change the variable type to integer.

# %%
def codificar_G2(variable):
    df2.loc[ df2[variable] == "0 Extrema esquerra", variable] = 0
    df2.loc[ df2[variable] == "10 Extrema dreta", variable] = 10
    df2.loc[ df2[variable] == "No ho sap", variable] = np.nan
    df2.loc[ df2[variable] == "No contesta", variable] = np.nan
    df2[variable].astype('Int64')

    
for var in vars_g2:
    codificar_G2(var)

# %% [markdown]
# - **Group 3:** Catalan independence - Spanish unionism ideology and ranking the ideology of other political parties

# %%
vars_g3 = list( var_an[var_an["Bloc_num"]==3]["Variables"] )
vars_g3
# Out:
# ['ESP_CAT_0_10',
#  'ESP_CAT_0_10_PP',
#  'ESP_CAT_0_10_ERC',
#  'ESP_CAT_0_10_PSC',
#  'ESP_CAT_0_10_CUP',
#  'ESP_CAT_0_10_JXCAT',
#  'ESP_CAT_0_10_CEC',
#  'ESP_CAT_0_10_VOX',
#  'ESP_CAT_0_10_ALIANCA']

# %% [markdown]
# I apply the codification and I change the variable type to integer.

# %%
def codificar_G3(variable):
    df2.loc[ df2[variable] == "0 Màxim espanyolisme", variable] = 0
    df2.loc[ df2[variable] == "10 Màxim catalanisme", variable] = 10
    df2.loc[ df2[variable] == "No ho sap", variable] = np.nan
    df2.loc[ df2[variable] == "No contesta", variable] = np.nan
    df2[variable].astype('Int64')

    
for var in vars_g3:
    codificar_G3(var)

# %% [markdown]
# - **Group 4:** Simpathy for groups and political parties

# %%
vars_g4 = list( var_an[var_an["Bloc_num"]==4]["Variables"] )
vars_g4
# Out:
# ['SIMPATIA_INDEPENDENTISTES_0_10',
#  'SIMPATIA_UNIONISTES_0_10',
#  'SIMPATIA_ESQUERRES_0_10',
#  'SIMPATIA_DRETES_0_10',
#  'SIMPATIA_FEMINISTES_0_10',
#  'SIMPATIA_CONTRARIS_FEMINISME_0_10',
#  'SIMPATIA_VOTANTS_PP_0_10',
#  'SIMPATIA_VOTANTS_PSC_0_10',
#  'SIMPATIA_VOTANTS_ERC_0_10',
#  'SIMPATIA_VOTANTS_CUP_0_10',
#  'SIMPATIA_VOTANTS_JXCAT_0_10',
#  'SIMPATIA_VOTANTS_CEC_0_10',
#  'SIMPATIA_VOTANTS_VOX_0_10',
#  'SIMPATIA_VOTANTS_ALIANCA_0_10']

# %% [markdown]
# I apply the codification and I change the variable type to integer.

# %%
def codificar_G4(variable):
    df2.loc[ df2[variable] == "0 Molta antipatia", variable] = 0
    df2.loc[ df2[variable] == "10 Molta simpatia", variable] = 10
    df2.loc[ df2[variable] == "No ho sap", variable] = np.nan
    df2.loc[ df2[variable] == "No contesta", variable] = np.nan
    df2[variable].astype('Int64')

    
for var in vars_g4:
    codificar_G4(var)

# %% [markdown]
# Finally I encode one last variable:

# %%
df2.loc[ df2["PERSONES_LLAR"]=="Una", "PERSONES_LLAR"] = 1
df2.loc[ df2["PERSONES_LLAR"]=="Dos", "PERSONES_LLAR"] = 2
df2.loc[ df2["PERSONES_LLAR"]=="Tres", "PERSONES_LLAR"] = 3
df2.loc[ df2["PERSONES_LLAR"]=="Quatre", "PERSONES_LLAR"] = 4
df2.loc[ df2["PERSONES_LLAR"]=="Cinc", "PERSONES_LLAR"] = 5
df2.loc[ df2["PERSONES_LLAR"]=="sis", "PERSONES_LLAR"] = 6
df2.loc[ df2["PERSONES_LLAR"]=="Set", "PERSONES_LLAR"] = 7
df2.loc[ df2["PERSONES_LLAR"]=="Vuit", "PERSONES_LLAR"] = 8
df2.loc[ df2["PERSONES_LLAR"]=="Nou", "PERSONES_LLAR"] = 9
df2.loc[ df2["PERSONES_LLAR"]=="Deu", "PERSONES_LLAR"] = 10
df2.loc[ df2["PERSONES_LLAR"]=="Onze", "PERSONES_LLAR"] = 11
df2.loc[ df2["PERSONES_LLAR"]=="No contesta", "PERSONES_LLAR"] = np.nan
df2["PERSONES_LLAR"] = df2["PERSONES_LLAR"].astype('float')
df2.loc[ df2["PERSONES_LLAR"].isna()==True, "PERSONES_LLAR"] = df2["PERSONES_LLAR"].mean()

# %% [markdown]
# Let's see how the numerical variables look after the encoding:

# %%
df2[list(var_an[var_an["Tipus"]=="n"]["Variables"])].head(20)
# Out:
#     EDAT VAL_GOV_CAT VAL_GOV_ESP IDEOL_0_10 IDEOL_0_10_PP IDEOL_0_10_ERC  \
# 0     19           4           6          6             9              3
# 1     59           2           8          2             8              3
# 2     68           3           5          3            10              8
# 3     51           0           4          0            10              5
# 4     70           3           8          3             9              7
# 5     36           6           5          2            10              3
# 6     53           5           3          4             8              4
# 7     71         NaN           3          5             5              5
# 8     38           0           0        NaN           NaN            NaN
# 9     62           4           5          4             5              5
# 10    47           8           1          5             5              1
# 11    27           3           3          0             8              4
# 12    77           5           5          5            10            NaN
# 13    74           5           5          5             5              4
# 14    64           5           2          5            10              5
# 15    32           5           5          2             9              6
# 16    56           5           5          5             6              4
# 17    51           5          10          5            10              5
# 18    49           5           8          6             0              4
# 19    51           0           0          6             7              9
#
#    IDEOL_0_10_PSC IDEOL_0_10_CUP IDEOL_0_10_JXCAT IDEOL_0_10_CEC  ...  \
# 0               6              4                3              5  ...
# 1               5              2                8              2  ...
# 2               4              2               10              3  ...
# 3               6              0               10              4  ...
# 4               5              1                9              1  ...
# 5               4            NaN                4              4  ...
# 6               5              3                7              4  ...
# 7               0             10               10              0  ...
# 8             NaN            NaN              NaN            NaN  ...
# 9               4            NaN                3              5  ...
# 10              1              5              NaN              1  ...
# 11              6              1                8              3  ...
# 12              5            NaN              NaN            NaN  ...
# 13              5              4                5              4  ...
# 14              5              5                5              5  ...
# 15              6              1                7              2  ...
# 16              4              3                6              4  ...
# 17              5              5                5              5  ...
# 18              8              3                3              6  ...
# 19             10             10                9              5  ...
#
#    SIMPATIA_CONTRARIS_FEMINISME_0_10 SIMPATIA_VOTANTS_PP_0_10  \
# 0                                  0                        4
# 1                                  2                        1
# 2                                  0                        0
# 3                                  0                        0
# 4                                  0                        0
# 5                                  3                        3
# 6                                  3                        3
# 7                                  5                        5
# 8                                  0                       10
# 9                                  4                        7
# 10                                 1                        8
# 11                                 0                        0
# 12                                 0                        1
# 13                                 5                        3
# 14                                 0                        5
# 15                                 0                        2
# 16                                 3                        5
# 17                                 5                        5
# 18                                 0                        0
# 19                                 2                        8
#
#    SIMPATIA_VOTANTS_PSC_0_10 SIMPATIA_VOTANTS_ERC_0_10  \
# 0                          5                         6
# 1                          7                         4
# 2                          5                         2
# 3                          5                         5
# 4                         10                         5
# 5                          7                         8
# 6                          5                         8
# 7                          5                         5
# 8                         10                       NaN
# 9                          6                         5
# 10                         0                        10
# 11                         4                         7
# 12                         5                         5
# 13                         8                         2
# 14                         5                         5
# 15                         5                         7
# 16                         5                         5
# 17                        10                         5
# 18                        10                         3
# 19                         0                         2
#
#    SIMPATIA_VOTANTS_CUP_0_10 SIMPATIA_VOTANTS_JXCAT_0_10  \
# 0                          6                           6
# 1                          6                           1
# 2                          2                           0
# 3                          8                           0
# 4                          0                           0
# 5                          8                           8
# 6                          7                           8
# 7                          5                           5
# 8                        NaN                         NaN
# 9                          4                           4
# 10                         8                         NaN
# 11                         9                           0
# 12                         5                           9
# 13                         3                           4
# 14                         5                           5
# 15                         9                           5
# 16                         3                           3
# 17                         0                           5
# 18                         0                           4
# 19                         3                           3
#
#    SIMPATIA_VOTANTS_CEC_0_10 SIMPATIA_VOTANTS_VOX_0_10  \
# 0                          6                         0
# 1                         10                         0
# 2                          2                         0
# 3                          8                         0
# 4                          7                         0
# 5                          5                         0
# 6                          7                         0
# 7                          5                         5
# 8                        NaN                         0
# 9                          4                         7
# 10                         1                         0
# 11                         8                         0
# 12                         5                         0
# 13                       NaN                         3
# 14                         5                         5
# 15                         9                         0
# 16                         3                         3
# 17                         5                         0
# 18                         4                         0
# 19                         4                         0
#
#    SIMPATIA_VOTANTS_ALIANCA_0_10 PERSONES_LLAR
# 0                              6           3.0
# 1                              1           2.0
# 2                              0           2.0
# 3                              0           1.0
# 4                              0           2.0
# 5                              8           4.0
# 6                              1           4.0
# 7                            NaN           3.0
# 8                            NaN           7.0
# 9                              6           1.0
# 10                           NaN           4.0
# 11                             0           3.0
# 12                             5           1.0
# 13                             3           1.0
# 14                             5           1.0
# 15                             0           2.0
# 16                             3           1.0
# 17                             5           3.0
# 18                             4           3.0
# 19                             4           4.0
#
# [20 rows x 36 columns]

# %% [markdown]
# _____________________

# %% [markdown]
# ## 02. Export the Data

# %% [markdown]
# Let's save the dataframe with the encoded variables as an excel

# %%
df2.to_excel('cleaned_df.xlsx',index=False)
